# %%
import numpy as np
import matplotlib.pyplot as plt
import polstance as ps

# %%
def func_interact()

# %%
a = np.arange(4)
b = a**2
plt.ylim(-2, 2)
plt.xlim(-2, 2)
plt.plot(a, b, '*')
plt.ylabel('some numbers')
plt.show()

# %%
np.random.uniform(0, 1, 1)
# Out:
# array([0.69687893])

# %%
#i1 = ps.Indiv([-2, 2, -2, 2])
l_ind = list()
for i in range(10):
    l_ind.append(ps.Indiv([-2, 2, -2, 2]))

# %%
plt.ylim(-2, 2)
plt.xlim(-2, 2)
for i in range(10):
    plt.plot(l_ind[i].x, l_ind[i].y, '*')
plt.ylabel('some numbers')
plt.show()

# %%
for i in range(5):
    ra = np.random.randint(0, len(l_ind))
    rb = np.random.randint(0, len(l_ind))
    #ps.interact(l_ind[ra], l_ind[rb], [4, 4], 0.01, ps.func1)
    ps.interact(l_ind[ra], l_ind[rb], [4, 4], 0.01, ps.func2)

# %%
plt.ylim(-2, 2)
plt.xlim(-2, 2)
for i in range(10):
    plt.plot(l_ind[i].x, l_ind[i].y, '*')
plt.ylabel('some numbers')
plt.show()

# %%
for i in range(10):
    plt.plot(l_ind[i].x, l_ind[i].y, '*')
plt.ylabel('some numbers')
plt.show()
